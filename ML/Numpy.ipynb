# %% [markdown]
# <a href="https://colab.research.google.com/github/raminguyen/Study-AI/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#find a maximum

sales = np.array([45, 12, 89, 34, 67])
products = np.array(["Alpha", "Beta", "Gamma", "Delta",  "Epsilon"])

# %%
sales
# Out:
# array([45, 12, 89, 34, 67])

# %%
products
# Out:
# array(['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon'], dtype='<U7')

# %%
#1: find the index of the highest seller
top_index = np.argmax(sales)

# %%
top_index
# Out:
# np.int64(2)

# %%
#2: see the number in the order
sortest_sales = np.sort(sales)
sortest_sales
# Out:
# array([12, 34, 45, 67, 89])

# %%
#3: sort the product names based on their sales

sorted_indices = np.argsort(sales)

sorted_indices
# Out:
# array([1, 3, 0, 4, 2])

# %%
sorted_product_names = products[sorted_indices]
sorted_product_names

#Beta product has the lowest price.
# Out:
# array(['Beta', 'Delta', 'Alpha', 'Epsilon', 'Gamma'], dtype='<U7')
