# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
students = {'hours': [29, 9, 10, 38, 16, 26, 50, 10, 30, 33, 43, 2, 39, 15, 44, 29, 41, 15, 24, 50],
            'test_results': [65, 7, 8, 76, 23, 56, 100, 3, 74, 48, 73, 0, 62, 37, 74, 40, 90, 42, 58, 100]}

# %%
import pandas as pd
student_data = pd.DataFrame(students)

# %%
student_data.head(15)
# Out:
#     hours  test_results
# 0      29            65
# 1       9             7
# 2      10             8
# 3      38            76
# 4      16            23
# 5      26            56
# 6      50           100
# 7      10             3
# 8      30            74
# 9      33            48
# 10     43            73
# 11      2             0
# 12     39            62
# 13     15            37
# 14     44            74

# %%
x = student_data.hours

# %%
x
# Out:
# 0     29
# 1      9
# 2     10
# 3     38
# 4     16
# 5     26
# 6     50
# 7     10
# 8     30
# 9     33
# 10    43
# 11     2
# 12    39
# 13    15
# 14    44
# 15    29
# 16    41
# 17    15
# 18    24
# 19    50
# Name: hours, dtype: int64

# %%
y = student_data.test_results

# %%
y
# Out:
# 0      65
# 1       7
# 2       8
# 3      76
# 4      23
# 5      56
# 6     100
# 7       3
# 8      74
# 9      48
# 10     73
# 11      0
# 12     62
# 13     37
# 14     74
# 15     40
# 16     90
# 17     42
# 18     58
# 19    100
# Name: test_results, dtype: int64

# %%
plt.scatter(x, y)

# %%
model = np.polyfit(x, y, 1)

model
# Out:
# array([ 2.01467487, -3.9057602 ])

# %%
#a: the regression coefficient
#b: intercept

#y = 2.01 * x - 3.905

# %%
predict = np.poly1d(model)

# %%
hours_studied = 20

# %%
predict(hours_studied)
# Out:
# np.float64(36.38773723347843)

# %%
#If students study for 20 hours, they receive 36 scores.
